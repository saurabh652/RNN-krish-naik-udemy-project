# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=10000
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### One Hot Representation
one_hot_repr=[one_hot(words,voc_size)for words in sent]
one_hot_repr
# Out:
# [[2903, 1533, 5479, 4267],
#  [2903, 1533, 5479, 3270],
#  [2903, 3770, 5479, 3167],
#  [588, 5552, 6078, 1616, 1801],
#  [588, 5552, 6078, 1616, 9728],
#  [3184, 2903, 9828, 5479, 4106],
#  [6393, 8598, 4008, 1616]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding
#from tensorflow.keras.processing.sequence import pad_sequences
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2903 1533 5479 4267]
#  [   0    0    0    0 2903 1533 5479 3270]
#  [   0    0    0    0 2903 3770 5479 3167]
#  [   0    0    0  588 5552 6078 1616 1801]
#  [   0    0    0  588 5552 6078 1616 9728]
#  [   0    0    0 3184 2903 9828 5479 4106]
#  [   0    0    0    0 6393 8598 4008 1616]]

# %%
## feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# array([[[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [ 0.02749241,  0.02099302, -0.0213989 ,  0.01828806,
#           0.00942714, -0.01959836,  0.01104284,  0.03551494,
#          -0.00452437,  0.03471306],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [-0.03590442, -0.02937448, -0.03247702, -0.01002612,
#           0.03696221,  0.00389346,  0.04843675,  0.02808664,
#          -0.02973992,  0.03867539]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [ 0.02749241,  0.02099302, -0.0213989 ,  0.01828806,
#           0.00942714, -0.01959836,  0.01104284,  0.03551494,
#          -0.00452437,  0.03471306],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [-0.04973052, -0.04732528, -0.02370253, -0.02746326,
#           0.04241172,  0.00278672, -0.04914477, -0.01332557,
#           0.03231755,  0.01945094]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [ 0.0142947 , -0.03884386,  0.04745246, -0.0172854 ,
#           0.0491823 ,  0.00796694, -0.01039479,  0.04482898,
#           0.02348696,  0.04637504],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [-0.01141211, -0.03600068,  0.04088623,  0.0332228 ,
#           0.04851988, -0.01180311, -0.04800281,  0.02397208,
#           0.00098244,  0.04443118]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [ 0.00199783,  0.03458282, -0.02991704,  0.02803762,
#           0.01504492,  0.00773634,  0.03601301, -0.0317207 ,
#          -0.00061178, -0.02906864],
#         [-0.01683812,  0.02722044, -0.04459829,  0.03539473,
#           0.02026561,  0.03071067, -0.0067461 ,  0.0377167 ,
#           0.03379248,  0.03257115],
#         [ 0.01557999,  0.00595142, -0.0237467 , -0.03230572,
#          -0.00251414,  0.04711943, -0.03990089,  0.01973516,
#          -0.03484399, -0.02223237],
#         [-0.04863508, -0.03552767,  0.04916959,  0.03057751,
#           0.01528894, -0.02124807,  0.04841167,  0.0293656 ,
#          -0.00083373,  0.01162276],
#         [-0.01640423, -0.01148029,  0.02528581,  0.02988955,
#          -0.03347876, -0.02179679, -0.00251912, -0.03857009,
#           0.01304977, -0.03303372]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [ 0.00199783,  0.03458282, -0.02991704,  0.02803762,
#           0.01504492,  0.00773634,  0.03601301, -0.0317207 ,
#          -0.00061178, -0.02906864],
#         [-0.01683812,  0.02722044, -0.04459829,  0.03539473,
#           0.02026561,  0.03071067, -0.0067461 ,  0.0377167 ,
#           0.03379248,  0.03257115],
#         [ 0.01557999,  0.00595142, -0.0237467 , -0.03230572,
#          -0.00251414,  0.04711943, -0.03990089,  0.01973516,
#          -0.03484399, -0.02223237],
#         [-0.04863508, -0.03552767,  0.04916959,  0.03057751,
#           0.01528894, -0.02124807,  0.04841167,  0.0293656 ,
#          -0.00083373,  0.01162276],
#         [-0.02601656,  0.00102377,  0.02185241,  0.03223119,
#           0.01324718,  0.03267564,  0.01985565,  0.02356286,
#          -0.03464939,  0.02154393]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.01635712,  0.03475333,  0.03173146,  0.0300186 ,
#          -0.00900699,  0.01614377,  0.00652921,  0.02897677,
#          -0.01948996,  0.02044774],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [-0.0005743 ,  0.03191236,  0.00692862,  0.03296658,
#          -0.02044413, -0.03631203, -0.03957014, -0.00511987,
#           0.03557951,  0.02989956],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [ 0.0086773 ,  0.02615957, -0.02709813, -0.0170872 ,
#          -0.02184674,  0.03332089,  0.00980209,  0.02173333,
#           0.02767862, -0.02890648]],
#
#        [[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.01495526, -0.00613575, -0.00044956, -0.01224393,
#           0.02524531,  0.0420223 ,  0.03937862, -0.03686418,
#          -0.02495282, -0.04983406],
#         [-0.03152993,  0.01143646,  0.03051924, -0.00400813,
#          -0.03067982,  0.03504345,  0.00690826, -0.02824165,
#          -0.00103142, -0.03613858],
#         [ 0.03072787,  0.03228832,  0.00655631, -0.00227575,
#           0.04293856,  0.04077634,  0.03258053, -0.00683583,
#          -0.00752841,  0.01391092],
#         [-0.04863508, -0.03552767,  0.04916959,  0.03057751,
#           0.01528894, -0.02124807,  0.04841167,  0.0293656 ,
#          -0.00083373,  0.01162276]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 2903, 1533, 5479, 4267], dtype=int32)

# %%
model.predict(np.expand_dims(embedded_docs[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# array([[[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [ 0.02749241,  0.02099302, -0.0213989 ,  0.01828806,
#           0.00942714, -0.01959836,  0.01104284,  0.03551494,
#          -0.00452437,  0.03471306],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [-0.03590442, -0.02937448, -0.03247702, -0.01002612,
#           0.03696221,  0.00389346,  0.04843675,  0.02808664,
#          -0.02973992,  0.03867539]]], dtype=float32)

# %%
print(embedded_docs[0].shape) 
print(np.array([embedded_docs[0]]).shape)
# Out:
# (8,)
# (1, 8)

# %%
model.predict(np.array([embedded_docs[0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# array([[[-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.0109839 , -0.02448984,  0.03369557,  0.01958844,
#           0.00857861, -0.04203583, -0.03231397,  0.0021488 ,
#           0.03346557,  0.04145148],
#         [-0.04540494, -0.04326111,  0.04285559, -0.0492935 ,
#          -0.02082852,  0.0210076 , -0.03627461,  0.04905483,
#          -0.04450932,  0.03798306],
#         [ 0.02749241,  0.02099302, -0.0213989 ,  0.01828806,
#           0.00942714, -0.01959836,  0.01104284,  0.03551494,
#          -0.00452437,  0.03471306],
#         [ 0.04728467, -0.0398142 , -0.02460198, -0.04493875,
#          -0.02296571, -0.03864165,  0.012479  , -0.01536395,
#          -0.02999575, -0.01674241],
#         [-0.03590442, -0.02937448, -0.03247702, -0.01002612,
#           0.03696221,  0.00389346,  0.04843675,  0.02808664,
#          -0.02973992,  0.03867539]]], dtype=float32)
